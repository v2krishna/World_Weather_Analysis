# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0        0  Butaritari      KI     80.65     overcast clouds   3.0707
# 1        1   Sembabule      UG     78.08     overcast clouds  -0.0772
# 2        5   Caravelas      BR     84.99           clear sky -17.7125
# 3        7    Araguari      BR     83.28     overcast clouds -18.6472
# 4        8      Atuona      PF     78.28          light rain  -9.8000
#
#         Lng                         Hotel Name
# 0  172.7902                 Isles Sunset Lodge
# 1   31.4567        Rainbow Motel ( Sembabule )
# 2  -39.2481             Pousada dos Navegantes
# 3  -48.1872  Big Executive Hotel - Araguari MG
# 4 -139.0333                        Villa Enata

# %%
clean_hotel_df =vacation_df.dropna()
clean_hotel_df.dropna()
# Out:
#      City_ID          City Country  Max Temp Current Description      Lat  \
# 0          0    Butaritari      KI     80.65     overcast clouds   3.0707
# 1          1     Sembabule      UG     78.08     overcast clouds  -0.0772
# 2          5     Caravelas      BR     84.99           clear sky -17.7125
# 3          7      Araguari      BR     83.28     overcast clouds -18.6472
# 4          8        Atuona      PF     78.28          light rain  -9.8000
# ..       ...           ...     ...       ...                 ...      ...
# 225      633  Port+Hedland      AU     84.20     overcast clouds -20.3167
# 226      638         Bonga      ET     76.24       broken clouds   7.2833
# 227      639        Sampit      ID     75.79     overcast clouds  -2.5333
# 228      642         Watsa      CD     91.24           clear sky   3.0372
# 229      645    Kralendijk      BQ     80.60       broken clouds  12.1500
#
#           Lng                           Hotel Name
# 0    172.7902                   Isles Sunset Lodge
# 1     31.4567          Rainbow Motel ( Sembabule )
# 2    -39.2481               Pousada dos Navegantes
# 3    -48.1872    Big Executive Hotel - Araguari MG
# 4   -139.0333                          Villa Enata
# ..        ...                                  ...
# 225  118.5667                  The Esplanade Hotel
# 226   36.2333                    Noona Noona Hotel
# 227  112.9500       Aquarius Boutique Hotel Sampit
# 228   29.5355                   Hôtel Le Pacifique
# 229  -68.2667  Divi Flamingo Beach Resort & Casino
#
# [230 rows x 8 columns]

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=True,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_country_df = clean_hotel_df.loc[clean_hotel_df["Country"]=="GF"]
vacation_country_df
# Out:
#      City_ID         City Country  Max Temp Current Description     Lat  \
# 66       183      Cayenne      GF     75.20                mist  4.9333
# 136      407     Iracoubo      GF     79.99     overcast clouds  5.4802
# 147      435    Sinnamary      GF     79.81     overcast clouds  5.3833
# 149      443  Grand-Santi      GF     81.86       broken clouds  4.2500
#
#          Lng                      Hotel Name
# 66  -52.3333                 Hôtel Le Dronmi
# 136 -53.2011              Le Gite D Iracoubo
# 147 -52.9500  ALETHEIA Appartement Sinnamary
# 149 -54.3833          Hotel La Villa Couacou

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]=="Araguari"]
vacation_end   = vacation_df.loc[vacation_df["City"]=="Araguari"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Jatai"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Piranhas"]
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Nova+Olimpia"]

# %%
vacation_stop3
# Out:
#      City_ID          City Country  Max Temp Current Description      Lat  \
# 207      588  Nova+Olimpia      BR     85.53       broken clouds -14.7972
#
#          Lng     Hotel Name
# 207 -57.2881  Motel glamour

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0])
end   = (vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0])
stop1 = (vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0])
stop2 = (vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0])
stop3 = (vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0])

# %%
(end, start, stop1, stop2,  stop3)
# Out:
# ((-18.6472, -48.1872),
#  (-18.6472, -48.1872),
#  (-17.8814, -51.7144),
#  (-16.4269, -51.8222),
#  (-14.7972, -57.2881))

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

# Create Map with route
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='WALKING')

fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID          City Country  Max Temp Current Description      Lat  \
# 0        7      Araguari      BR     83.28     overcast clouds -18.6472
# 1      156         Jatai      BR     83.91          few clouds -17.8814
# 2      538      Piranhas      BR     85.96       broken clouds -16.4269
# 3      588  Nova+Olimpia      BR     85.53       broken clouds -14.7972
#
#        Lng                         Hotel Name
# 0 -48.1872  Big Executive Hotel - Araguari MG
# 1 -51.7144                   Hotel Califórnia
# 2 -51.8222                     Planalto Hotel
# 3 -57.2881                      Motel glamour

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=True,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
