# %%
# import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

# import  weather_api_key
from config import weather_api_key

from datetime import datetime

# %%
# create a set of random lats and longs combintation

lats = np.random.uniform(-90 , 90, size =2000)
lngs = np.random.uniform(-180,180, size =2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Citypy module to find the nearest city
from citipy import citipy
coordinates = list(lats_lngs)

# %%
#create the list of cities which are unique
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
cities
len(cities)
# Out:
# 785

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# city_url = url+"&q="+"Boston"
# city_weather = requests.get(city_url).json()
# city_weather['weather'][0]['description']

# %%
#Create an empty list to hold the weather data
city_data =[]

#print the begining of the logging
print("Begining Data Retrieval")
print("-----------------------")

#create counters
record_count = 1 
set_count = 1


# Loop through all the cities in our list:
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes:
    if (i%50==0 and i>50):
        set_count +=1
        record_count =1
    city = city.replace(" ","+")
    # create endpoint URL with each city.
    city_url = url+"&q="+city
    
    #logging the URL record, and set numbers and the city
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    #print(city_url)
    
    # Add 1  to the record count 
    record_count +=1
    
    # Run an API request for each of the cities.
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining Data Retrieval
# -----------------------
# Processing Record 1 of set 1 | rikitea
# Processing Record 2 of set 1 | ponta+do+sol
# Processing Record 3 of set 1 | cooma
# Processing Record 4 of set 1 | kodinsk
# Processing Record 5 of set 1 | kontagora
# Processing Record 6 of set 1 | ushuaia
# Processing Record 7 of set 1 | punta+arenas
# Processing Record 8 of set 1 | stephenville+crossing
# Processing Record 9 of set 1 | mataura
# Processing Record 10 of set 1 | souillac
# Processing Record 11 of set 1 | sinnamary
# Processing Record 12 of set 1 | eyl
# Processing Record 13 of set 1 | jais
# Processing Record 14 of set 1 | laon
# Processing Record 15 of set 1 | codrington
# Processing Record 16 of set 1 | auki
# Processing Record 17 of set 1 | nikolskoye
# Processing Record 18 of set 1 | dembi+dolo
# Processing Record 19 of set 1 | alotau
# City not found. Skipping...
# Processing Record 20 of set 1 | tuktoyaktuk
# Processing Record 21 of set 1 | pozo+colorado
# Processing Record 22 of set 1 | vaini
# Processing Record 23 of set 1 | busselton
# Processing Record 24 of set 1 | avera
# Processing Record 25 of set 1 | am+timan
# Processing Record 26 of set 1 | clevelandia
# Processing Record 27 of set 1 | hilo
# Processing Record 28 of set 1 | mar+del+plata
# Processing Record 29 of set 1 | hami
# Processing Record 30 of set 1 | mersing
# Processing Record 31 of set 1 | labuhan
# Processing Record 32 of set 1 | louisbourg
# City not found. Skipping...
# Processing Record 33 of set 1 | tasiilaq
# Processing Record 34 of set 1 | kruisfontein
# Processing Record 35 of set 1 | belushya+guba
# City not found. Skipping...
# Processing Record 36 of set 1 | jinchang
# Processing Record 37 of set 1 | avarua
# Processing Record 38 of set 1 | daxian
# City not found. Skipping...
# Processing Record 39 of set 1 | camopi
# Processing Record 40 of set 1 | provideniya
# Processing Record 41 of set 1 | fortuna
# Processing Record 42 of set 1 | port+keats
# Processing Record 43 of set 1 | castro
# Processing Record 44 of set 1 | tiznit
# Processing Record 45 of set 1 | lorengau
# Processing Record 46 of set 1 | lebu
# Processing Record 47 of set 1 | marshall
# Processing Record 48 of set 1 | bethel
# Processing Record 49 of set 1 | cidreira
# Processing Record 50 of set 1 | cherskiy
# Processing Record 51 of set 1 | geraldton
# Processing Record 52 of set 1 | hermanus
# Processing Record 53 of set 1 | severo-kurilsk
# Processing Record 54 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 55 of set 1 | vaitupu
# City not found. Skipping...
# Processing Record 56 of set 1 | pipri
# Processing Record 57 of set 1 | dikson
# Processing Record 58 of set 1 | alofi
# Processing Record 59 of set 1 | saint-philippe
# Processing Record 60 of set 1 | butaritari
# Processing Record 61 of set 1 | tiksi
# Processing Record 62 of set 1 | ribeira+grande
# Processing Record 63 of set 1 | saint+anthony
# Processing Record 64 of set 1 | port+blair
# Processing Record 65 of set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 66 of set 1 | port+alfred
# Processing Record 67 of set 1 | narsaq
# Processing Record 68 of set 1 | kushima
# Processing Record 69 of set 1 | pecos
# Processing Record 70 of set 1 | bredasdorp
# Processing Record 71 of set 1 | port+elizabeth
# Processing Record 72 of set 1 | kafanchan
# Processing Record 73 of set 1 | new+norfolk
# Processing Record 74 of set 1 | albany
# Processing Record 75 of set 1 | barrow
# Processing Record 76 of set 1 | thompson
# Processing Record 77 of set 1 | leningradskiy
# Processing Record 78 of set 1 | puerto+ayora
# Processing Record 79 of set 1 | illapel
# Processing Record 80 of set 1 | naron
# Processing Record 81 of set 1 | rio+claro
# Processing Record 82 of set 1 | norman+wells
# Processing Record 83 of set 1 | lasa
# Processing Record 84 of set 1 | pinega
# Processing Record 85 of set 1 | bluff
# Processing Record 86 of set 1 | zhigansk
# Processing Record 87 of set 1 | talnakh
# Processing Record 88 of set 1 | tromso
# Processing Record 89 of set 1 | hualmay
# Processing Record 90 of set 1 | galeana
# Processing Record 91 of set 1 | coquimbo
# Processing Record 92 of set 1 | kaitangata
# Processing Record 93 of set 1 | cacador
# Processing Record 94 of set 1 | karpathos
# Processing Record 95 of set 1 | torbay
# Processing Record 96 of set 1 | chokurdakh
# Processing Record 97 of set 1 | praia+da+vitoria
# Processing Record 98 of set 1 | marovoay
# Processing Record 99 of set 1 | dawson+creek
# Processing Record 100 of set 1 | grand+river+south+east
# City not found. Skipping...
# Processing Record 1 of set 2 | vostok
# Processing Record 2 of set 2 | yellowknife
# Processing Record 3 of set 2 | bakchar
# Processing Record 4 of set 2 | anzhero-sudzhensk
# Processing Record 5 of set 2 | tucuman
# Processing Record 6 of set 2 | ahuimanu
# Processing Record 7 of set 2 | kattivakkam
# Processing Record 8 of set 2 | elliot+lake
# Processing Record 9 of set 2 | hambantota
# Processing Record 10 of set 2 | bargal
# City not found. Skipping...
# Processing Record 11 of set 2 | georgetown
# Processing Record 12 of set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of set 2 | bengkulu
# Processing Record 14 of set 2 | cavaillon
# Processing Record 15 of set 2 | mtsensk
# Processing Record 16 of set 2 | kapaa
# Processing Record 17 of set 2 | mys+shmidta
# City not found. Skipping...
# Processing Record 18 of set 2 | ettenheim
# Processing Record 19 of set 2 | esperance
# Processing Record 20 of set 2 | khatanga
# Processing Record 21 of set 2 | poum
# Processing Record 22 of set 2 | tahoua
# Processing Record 23 of set 2 | road+town
# Processing Record 24 of set 2 | virden
# Processing Record 25 of set 2 | hobart
# Processing Record 26 of set 2 | nanortalik
# Processing Record 27 of set 2 | walvis+bay
# Processing Record 28 of set 2 | arraial+do+cabo
# Processing Record 29 of set 2 | saint-augustin
# Processing Record 30 of set 2 | homer
# Processing Record 31 of set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of set 2 | zempoala
# Processing Record 33 of set 2 | gizo
# Processing Record 34 of set 2 | mbini
# Processing Record 35 of set 2 | caravelas
# Processing Record 36 of set 2 | cape+town
# Processing Record 37 of set 2 | sengiley
# Processing Record 38 of set 2 | taoudenni
# Processing Record 39 of set 2 | juneau
# Processing Record 40 of set 2 | wanning
# Processing Record 41 of set 2 | abu+kamal
# Processing Record 42 of set 2 | shenjiamen
# Processing Record 43 of set 2 | eisenerz
# Processing Record 44 of set 2 | doka
# Processing Record 45 of set 2 | wagar
# Processing Record 46 of set 2 | mus
# Processing Record 47 of set 2 | atuona
# Processing Record 48 of set 2 | banfora
# Processing Record 49 of set 2 | bartica
# Processing Record 50 of set 2 | cockburn+town
# Processing Record 1 of set 3 | lagos
# Processing Record 2 of set 3 | sao+joao+da+barra
# Processing Record 3 of set 3 | barahona
# Processing Record 4 of set 3 | bambous+virieux
# Processing Record 5 of set 3 | kodiak
# Processing Record 6 of set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of set 3 | saldanha
# Processing Record 8 of set 3 | buqayq
# City not found. Skipping...
# Processing Record 9 of set 3 | pevek
# Processing Record 10 of set 3 | cabo+san+lucas
# Processing Record 11 of set 3 | haibowan
# City not found. Skipping...
# Processing Record 12 of set 3 | bilma
# Processing Record 13 of set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of set 3 | yerbogachen
# Processing Record 15 of set 3 | katsuura
# Processing Record 16 of set 3 | crestview
# Processing Record 17 of set 3 | bushehr
# Processing Record 18 of set 3 | vilhena
# Processing Record 19 of set 3 | hithadhoo
# Processing Record 20 of set 3 | galesong
# Processing Record 21 of set 3 | husavik
# Processing Record 22 of set 3 | lolua
# City not found. Skipping...
# Processing Record 23 of set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of set 3 | north+platte
# Processing Record 25 of set 3 | buariki
# City not found. Skipping...
# Processing Record 26 of set 3 | alta+floresta
# Processing Record 27 of set 3 | port+augusta
# Processing Record 28 of set 3 | podsineye
# Processing Record 29 of set 3 | upernavik
# Processing Record 30 of set 3 | saskylakh
# Processing Record 31 of set 3 | riverton
# Processing Record 32 of set 3 | bandarbeyla
# Processing Record 33 of set 3 | sabang
# Processing Record 34 of set 3 | nuuk
# Processing Record 35 of set 3 | bealanana
# Processing Record 36 of set 3 | nyzy
# Processing Record 37 of set 3 | bilibino
# Processing Record 38 of set 3 | cayenne
# Processing Record 39 of set 3 | meridian
# Processing Record 40 of set 3 | ranot
# Processing Record 41 of set 3 | baiyin
# Processing Record 42 of set 3 | saint-pierre
# Processing Record 43 of set 3 | jamestown
# Processing Record 44 of set 3 | vao
# Processing Record 45 of set 3 | victoria
# Processing Record 46 of set 3 | san+andres
# Processing Record 47 of set 3 | udachnyy
# Processing Record 48 of set 3 | mumford
# Processing Record 49 of set 3 | fairbanks
# Processing Record 50 of set 3 | beringovskiy
# Processing Record 1 of set 4 | benghazi
# Processing Record 2 of set 4 | cap+malheureux
# Processing Record 3 of set 4 | dundee
# Processing Record 4 of set 4 | chardara
# Processing Record 5 of set 4 | lavrentiya
# Processing Record 6 of set 4 | neiafu
# Processing Record 7 of set 4 | muros
# Processing Record 8 of set 4 | tuatapere
# Processing Record 9 of set 4 | wollongong
# Processing Record 10 of set 4 | qaanaaq
# Processing Record 11 of set 4 | jamabalud
# City not found. Skipping...
# Processing Record 12 of set 4 | alekseyevsk
# Processing Record 13 of set 4 | mastic+beach
# Processing Record 14 of set 4 | marcona
# City not found. Skipping...
# Processing Record 15 of set 4 | songjianghe
# Processing Record 16 of set 4 | beberibe
# Processing Record 17 of set 4 | veraval
# Processing Record 18 of set 4 | palmer
# Processing Record 19 of set 4 | kintampo
# Processing Record 20 of set 4 | pangai
# Processing Record 21 of set 4 | agadez
# Processing Record 22 of set 4 | agasegyhaza
# Processing Record 23 of set 4 | along
# Processing Record 24 of set 4 | sao+miguel+do+araguaia
# Processing Record 25 of set 4 | nola
# Processing Record 26 of set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of set 4 | sarlat-la-caneda
# Processing Record 28 of set 4 | korla
# Processing Record 29 of set 4 | akom
# Processing Record 30 of set 4 | ngukurr
# City not found. Skipping...
# Processing Record 31 of set 4 | faanui
# Processing Record 32 of set 4 | kibungo
# Processing Record 33 of set 4 | pangnirtung
# Processing Record 34 of set 4 | mishan
# Processing Record 35 of set 4 | vitim
# Processing Record 36 of set 4 | te+anau
# Processing Record 37 of set 4 | awbari
# Processing Record 38 of set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of set 4 | priladozhskiy
# Processing Record 40 of set 4 | ho
# City not found. Skipping...
# Processing Record 41 of set 4 | chapais
# Processing Record 42 of set 4 | tiarei
# Processing Record 43 of set 4 | kushiro
# Processing Record 44 of set 4 | brufut
# Processing Record 45 of set 4 | srandakan
# Processing Record 46 of set 4 | baruun-urt
# Processing Record 47 of set 4 | bacolod
# Processing Record 48 of set 4 | zittau
# Processing Record 49 of set 4 | porosozero
# Processing Record 50 of set 4 | dicabisagan
# Processing Record 1 of set 5 | napa
# Processing Record 2 of set 5 | aswan
# Processing Record 3 of set 5 | nemuro
# Processing Record 4 of set 5 | ballina
# Processing Record 5 of set 5 | comodoro+rivadavia
# Processing Record 6 of set 5 | kloulklubed
# Processing Record 7 of set 5 | nome
# Processing Record 8 of set 5 | salalah
# Processing Record 9 of set 5 | aklavik
# Processing Record 10 of set 5 | buala
# Processing Record 11 of set 5 | formoso+do+araguaia
# City not found. Skipping...
# Processing Record 12 of set 5 | churapcha
# Processing Record 13 of set 5 | sarankhola
# Processing Record 14 of set 5 | kyabram
# Processing Record 15 of set 5 | beloha
# Processing Record 16 of set 5 | san+jose
# Processing Record 17 of set 5 | bonavista
# Processing Record 18 of set 5 | burnie
# Processing Record 19 of set 5 | clyde+river
# Processing Record 20 of set 5 | cairns
# Processing Record 21 of set 5 | boditi
# Processing Record 22 of set 5 | mineros
# Processing Record 23 of set 5 | wellington
# Processing Record 24 of set 5 | kavieng
# Processing Record 25 of set 5 | kita
# Processing Record 26 of set 5 | ilulissat
# Processing Record 27 of set 5 | acoyapa
# Processing Record 28 of set 5 | mount+pleasant
# Processing Record 29 of set 5 | ancud
# Processing Record 30 of set 5 | hamilton
# Processing Record 31 of set 5 | adrar
# Processing Record 32 of set 5 | pedernales
# Processing Record 33 of set 5 | paraopeba
# Processing Record 34 of set 5 | juybar
# Processing Record 35 of set 5 | porto+novo
# Processing Record 36 of set 5 | kahului
# Processing Record 37 of set 5 | mossendjo
# Processing Record 38 of set 5 | nizhniy+odes
# Processing Record 39 of set 5 | bissora
# Processing Record 40 of set 5 | naze
# Processing Record 41 of set 5 | iqaluit
# Processing Record 42 of set 5 | east+london
# Processing Record 43 of set 5 | mehamn
# Processing Record 44 of set 5 | hasaki
# Processing Record 45 of set 5 | chuy
# Processing Record 46 of set 5 | ghanzi
# Processing Record 47 of set 5 | sistranda
# Processing Record 48 of set 5 | berdigestyakh
# Processing Record 49 of set 5 | sitka
# Processing Record 50 of set 5 | aniva
# Processing Record 1 of set 6 | havelock
# Processing Record 2 of set 6 | viedma
# Processing Record 3 of set 6 | grand+gaube
# Processing Record 4 of set 6 | margate
# Processing Record 5 of set 6 | goderich
# Processing Record 6 of set 6 | saint+george
# Processing Record 7 of set 6 | yar-sale
# Processing Record 8 of set 6 | quatre+cocos
# Processing Record 9 of set 6 | carnduff
# Processing Record 10 of set 6 | partanna
# Processing Record 11 of set 6 | miranda+de+ebro
# Processing Record 12 of set 6 | sao+joao+batista
# Processing Record 13 of set 6 | sur
# Processing Record 14 of set 6 | sorland
# Processing Record 15 of set 6 | aksu
# Processing Record 16 of set 6 | the+valley
# Processing Record 17 of set 6 | ewa+beach
# Processing Record 18 of set 6 | chemal
# Processing Record 19 of set 6 | mogadishu
# Processing Record 20 of set 6 | capela
# Processing Record 21 of set 6 | ciudad+bolivar
# Processing Record 22 of set 6 | winchester
# Processing Record 23 of set 6 | tilichiki
# Processing Record 24 of set 6 | gwadar
# Processing Record 25 of set 6 | nara
# Processing Record 26 of set 6 | hammerfest
# Processing Record 27 of set 6 | bozeman
# Processing Record 28 of set 6 | kasuga
# Processing Record 29 of set 6 | makakilo+city
# Processing Record 30 of set 6 | lakes+entrance
# Processing Record 31 of set 6 | la+ronge
# Processing Record 32 of set 6 | luderitz
# Processing Record 33 of set 6 | bathsheba
# Processing Record 34 of set 6 | coolum+beach
# Processing Record 35 of set 6 | hanmer+springs
# Processing Record 36 of set 6 | abu+dhabi
# Processing Record 37 of set 6 | guerrero+negro
# Processing Record 38 of set 6 | san+patricio
# Processing Record 39 of set 6 | san+carlos+de+bariloche
# Processing Record 40 of set 6 | mahebourg
# Processing Record 41 of set 6 | mount+gambier
# Processing Record 42 of set 6 | lakselv
# Processing Record 43 of set 6 | savelugu
# Processing Record 44 of set 6 | umba
# Processing Record 45 of set 6 | gibsons
# Processing Record 46 of set 6 | callaway
# Processing Record 47 of set 6 | phan+thiet
# Processing Record 48 of set 6 | skjervoy
# Processing Record 49 of set 6 | dhidhdhoo
# Processing Record 50 of set 6 | wairoa
# Processing Record 1 of set 7 | parana
# Processing Record 2 of set 7 | itarema
# Processing Record 3 of set 7 | ambulu
# Processing Record 4 of set 7 | el+alto
# Processing Record 5 of set 7 | constitucion
# Processing Record 6 of set 7 | ikungi
# Processing Record 7 of set 7 | sao+gabriel+da+cachoeira
# Processing Record 8 of set 7 | karratha
# Processing Record 9 of set 7 | asfi
# Processing Record 10 of set 7 | jahrom
# City not found. Skipping...
# Processing Record 11 of set 7 | bud
# Processing Record 12 of set 7 | aranos
# Processing Record 13 of set 7 | caxito
# Processing Record 14 of set 7 | janauba
# Processing Record 15 of set 7 | tumaco
# Processing Record 16 of set 7 | santa+rita+do+sapucai
# Processing Record 17 of set 7 | aflu
# City not found. Skipping...
# Processing Record 18 of set 7 | pekalongan
# Processing Record 19 of set 7 | saint-leu
# Processing Record 20 of set 7 | khandyga
# Processing Record 21 of set 7 | ruatoria
# City not found. Skipping...
# Processing Record 22 of set 7 | jomalig
# City not found. Skipping...
# Processing Record 23 of set 7 | port+macquarie
# Processing Record 24 of set 7 | yatou
# Processing Record 25 of set 7 | snezhnogorsk
# Processing Record 26 of set 7 | pasighat
# Processing Record 27 of set 7 | washington
# Processing Record 28 of set 7 | atikokan
# Processing Record 29 of set 7 | pisco
# Processing Record 30 of set 7 | keetmanshoop
# Processing Record 31 of set 7 | gazanjyk
# Processing Record 32 of set 7 | svetlyy
# Processing Record 33 of set 7 | panalingaan
# Processing Record 34 of set 7 | namwala
# Processing Record 35 of set 7 | pangkalanbuun
# Processing Record 36 of set 7 | tuy+hoa
# Processing Record 37 of set 7 | moose+factory
# Processing Record 38 of set 7 | lethem
# Processing Record 39 of set 7 | vallenar
# Processing Record 40 of set 7 | arman
# Processing Record 41 of set 7 | luanda
# Processing Record 42 of set 7 | honggang
# Processing Record 43 of set 7 | solwezi
# Processing Record 44 of set 7 | seminole
# Processing Record 45 of set 7 | murgab
# Processing Record 46 of set 7 | sherlovaya+gora
# Processing Record 47 of set 7 | northam
# Processing Record 48 of set 7 | lumut
# Processing Record 49 of set 7 | nguiu
# City not found. Skipping...
# Processing Record 50 of set 7 | palmares+do+sul
# Processing Record 1 of set 8 | great+yarmouth
# Processing Record 2 of set 8 | pitimbu
# Processing Record 3 of set 8 | lebork
# Processing Record 4 of set 8 | igarka
# Processing Record 5 of set 8 | sangar
# Processing Record 6 of set 8 | boddam
# Processing Record 7 of set 8 | mayo
# Processing Record 8 of set 8 | pedreiras
# Processing Record 9 of set 8 | vila+velha
# Processing Record 10 of set 8 | kapit
# Processing Record 11 of set 8 | barcelos
# Processing Record 12 of set 8 | coahuayana
# Processing Record 13 of set 8 | gat
# Processing Record 14 of set 8 | fuyu
# Processing Record 15 of set 8 | poso
# Processing Record 16 of set 8 | siniscola
# Processing Record 17 of set 8 | kamenka
# Processing Record 18 of set 8 | ipixuna
# Processing Record 19 of set 8 | vila
# Processing Record 20 of set 8 | hanzhong
# Processing Record 21 of set 8 | wajir
# Processing Record 22 of set 8 | changping
# Processing Record 23 of set 8 | aksarka
# Processing Record 24 of set 8 | sharjah
# Processing Record 25 of set 8 | belyy+yar
# Processing Record 26 of set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of set 8 | borogontsy
# Processing Record 28 of set 8 | dingle
# Processing Record 29 of set 8 | carnarvon
# Processing Record 30 of set 8 | ringsted
# Processing Record 31 of set 8 | pringsewu
# Processing Record 32 of set 8 | houma
# Processing Record 33 of set 8 | snasa
# Processing Record 34 of set 8 | zinacantan
# Processing Record 35 of set 8 | salta
# Processing Record 36 of set 8 | porlamar
# Processing Record 37 of set 8 | college
# Processing Record 38 of set 8 | grand-lahou
# Processing Record 39 of set 8 | griffith
# Processing Record 40 of set 8 | meulaboh
# Processing Record 41 of set 8 | cap-aux-meules
# Processing Record 42 of set 8 | vestmannaeyjar
# Processing Record 43 of set 8 | eureka
# Processing Record 44 of set 8 | san+cristobal
# Processing Record 45 of set 8 | kavaratti
# Processing Record 46 of set 8 | padang
# Processing Record 47 of set 8 | marsh+harbour
# Processing Record 48 of set 8 | hervey+bay
# Processing Record 49 of set 8 | dezful
# Processing Record 50 of set 8 | airai
# Processing Record 1 of set 9 | aquiraz
# Processing Record 2 of set 9 | usoke
# Processing Record 3 of set 9 | litovko
# Processing Record 4 of set 9 | rio+rancho
# Processing Record 5 of set 9 | harper
# Processing Record 6 of set 9 | mackay
# Processing Record 7 of set 9 | maarianhamina
# Processing Record 8 of set 9 | nishihara
# Processing Record 9 of set 9 | san+quintin
# Processing Record 10 of set 9 | bekesszentandras
# Processing Record 11 of set 9 | magadan
# Processing Record 12 of set 9 | alice+springs
# Processing Record 13 of set 9 | rabo+de+peixe
# Processing Record 14 of set 9 | yangambi
# Processing Record 15 of set 9 | yulara
# Processing Record 16 of set 9 | basco
# Processing Record 17 of set 9 | sakakah
# Processing Record 18 of set 9 | mwinilunga
# Processing Record 19 of set 9 | kongolo
# Processing Record 20 of set 9 | strezhevoy
# Processing Record 21 of set 9 | lyngseidet
# Processing Record 22 of set 9 | ambon
# Processing Record 23 of set 9 | puunsi
# City not found. Skipping...
# Processing Record 24 of set 9 | vryheid
# Processing Record 25 of set 9 | manta
# Processing Record 26 of set 9 | xunchang
# Processing Record 27 of set 9 | kalengwa
# Processing Record 28 of set 9 | lewisporte
# Processing Record 29 of set 9 | korcula
# Processing Record 30 of set 9 | atar
# Processing Record 31 of set 9 | jacareacanga
# Processing Record 32 of set 9 | sao+filipe
# Processing Record 33 of set 9 | kununurra
# Processing Record 34 of set 9 | saleaula
# City not found. Skipping...
# Processing Record 35 of set 9 | temaraia
# City not found. Skipping...
# Processing Record 36 of set 9 | lata
# Processing Record 37 of set 9 | kalmunai
# Processing Record 38 of set 9 | watertown
# Processing Record 39 of set 9 | carutapera
# Processing Record 40 of set 9 | whitley+bay
# Processing Record 41 of set 9 | mendahara
# City not found. Skipping...
# Processing Record 42 of set 9 | madang
# Processing Record 43 of set 9 | kaeo
# Processing Record 44 of set 9 | zabaykalsk
# Processing Record 45 of set 9 | phalaborwa
# Processing Record 46 of set 9 | martinho+campos
# Processing Record 47 of set 9 | hofn
# Processing Record 48 of set 9 | lompoc
# Processing Record 49 of set 9 | kirakira
# Processing Record 50 of set 9 | sioux+lookout
# Processing Record 1 of set 10 | vieux-habitants
# Processing Record 2 of set 10 | zabol
# Processing Record 3 of set 10 | imbituba
# Processing Record 4 of set 10 | tsiroanomandidy
# Processing Record 5 of set 10 | necochea
# Processing Record 6 of set 10 | buluang
# Processing Record 7 of set 10 | peskovka
# Processing Record 8 of set 10 | iracoubo
# Processing Record 9 of set 10 | luena
# Processing Record 10 of set 10 | deputatskiy
# Processing Record 11 of set 10 | vargem+grande
# Processing Record 12 of set 10 | alyangula
# Processing Record 13 of set 10 | klaksvik
# Processing Record 14 of set 10 | isangel
# Processing Record 15 of set 10 | beatrice
# Processing Record 16 of set 10 | hokitika
# Processing Record 17 of set 10 | toliary
# City not found. Skipping...
# Processing Record 18 of set 10 | urucui
# Processing Record 19 of set 10 | sydney
# Processing Record 20 of set 10 | bana
# Processing Record 21 of set 10 | ambilobe
# Processing Record 22 of set 10 | matay
# Processing Record 23 of set 10 | srednekolymsk
# Processing Record 24 of set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 25 of set 10 | manzil+tamim
# City not found. Skipping...
# Processing Record 26 of set 10 | luang+prabang
# Processing Record 27 of set 10 | fianga
# City not found. Skipping...
# Processing Record 28 of set 10 | dekoa
# City not found. Skipping...
# Processing Record 29 of set 10 | dongsheng
# Processing Record 30 of set 10 | duz
# City not found. Skipping...
# Processing Record 31 of set 10 | shakawe
# Processing Record 32 of set 10 | haines+junction
# Processing Record 33 of set 10 | witu
# Processing Record 34 of set 10 | mrirt
# City not found. Skipping...
# Processing Record 35 of set 10 | porto+walter
# Processing Record 36 of set 10 | westport
# Processing Record 37 of set 10 | nicoya
# Processing Record 38 of set 10 | muroto
# Processing Record 39 of set 10 | camana
# Processing Record 40 of set 10 | lakeside
# Processing Record 41 of set 10 | kuche
# City not found. Skipping...
# Processing Record 42 of set 10 | arona
# Processing Record 43 of set 10 | poronaysk
# Processing Record 44 of set 10 | betong
# Processing Record 45 of set 10 | rocha
# Processing Record 46 of set 10 | tarudant
# City not found. Skipping...
# Processing Record 47 of set 10 | pafos
# Processing Record 48 of set 10 | mareeba
# Processing Record 49 of set 10 | trairi
# Processing Record 50 of set 10 | bandundu
# Processing Record 1 of set 11 | san+luis
# Processing Record 2 of set 11 | waddan
# Processing Record 3 of set 11 | ahipara
# Processing Record 4 of set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 5 of set 11 | dangriga
# Processing Record 6 of set 11 | bridlington
# Processing Record 7 of set 11 | feira+de+santana
# Processing Record 8 of set 11 | shugurovo
# Processing Record 9 of set 11 | anito
# Processing Record 10 of set 11 | zhangye
# Processing Record 11 of set 11 | crab+hill
# City not found. Skipping...
# Processing Record 12 of set 11 | petropavlovsk-kamchatskiy
# Processing Record 13 of set 11 | tessalit
# Processing Record 14 of set 11 | kjollefjord
# Processing Record 15 of set 11 | talas
# Processing Record 16 of set 11 | yumen
# Processing Record 17 of set 11 | kytlym
# City not found. Skipping...
# Processing Record 18 of set 11 | la+sarre
# Processing Record 19 of set 11 | panjakent
# Processing Record 20 of set 11 | nerang
# Processing Record 21 of set 11 | bourges
# Processing Record 22 of set 11 | zhigalovo
# Processing Record 23 of set 11 | cam+pha
# City not found. Skipping...
# Processing Record 24 of set 11 | gopalpur
# Processing Record 25 of set 11 | wattegama
# Processing Record 26 of set 11 | krasnoselkup
# Processing Record 27 of set 11 | bahile
# Processing Record 28 of set 11 | sobolevo
# Processing Record 29 of set 11 | sawakin
# Processing Record 30 of set 11 | san+vicente+de+canete
# Processing Record 31 of set 11 | mocuba
# Processing Record 32 of set 11 | carauari
# Processing Record 33 of set 11 | tema
# Processing Record 34 of set 11 | bajos+de+haina
# Processing Record 35 of set 11 | thunder+bay
# Processing Record 36 of set 11 | iwaki
# Processing Record 37 of set 11 | flinders
# Processing Record 38 of set 11 | itaperucu
# Processing Record 39 of set 11 | kormilovka
# Processing Record 40 of set 11 | kutum
# Processing Record 41 of set 11 | agboville
# Processing Record 42 of set 11 | casablanca
# Processing Record 43 of set 11 | seoul
# Processing Record 44 of set 11 | broken+hill
# Processing Record 45 of set 11 | najran
# Processing Record 46 of set 11 | bakel
# Processing Record 47 of set 11 | port+hardy
# Processing Record 48 of set 11 | belmonte
# Processing Record 49 of set 11 | soyo
# Processing Record 50 of set 11 | diffa
# Processing Record 1 of set 12 | asayita
# City not found. Skipping...
# Processing Record 2 of set 12 | teahupoo
# Processing Record 3 of set 12 | rio+grande
# Processing Record 4 of set 12 | waipawa
# Processing Record 5 of set 12 | chabahar
# Processing Record 6 of set 12 | san+pedro+del+pinatar
# Processing Record 7 of set 12 | henties+bay
# Processing Record 8 of set 12 | dryden
# Processing Record 9 of set 12 | piura
# Processing Record 10 of set 12 | moerai
# Processing Record 11 of set 12 | abeche
# Processing Record 12 of set 12 | bonthe
# Processing Record 13 of set 12 | jinji
# Processing Record 14 of set 12 | san+policarpo
# Processing Record 15 of set 12 | ippy
# Processing Record 16 of set 12 | tay+ninh
# Processing Record 17 of set 12 | lamont
# Processing Record 18 of set 12 | deniliquin
# Processing Record 19 of set 12 | wawa
# Processing Record 20 of set 12 | paraiso
# Processing Record 21 of set 12 | vanavara
# Processing Record 22 of set 12 | hegang
# Processing Record 23 of set 12 | nouakchott
# Processing Record 24 of set 12 | verkhnyaya+inta
# Processing Record 25 of set 12 | maniitsoq
# Processing Record 26 of set 12 | talawdi
# City not found. Skipping...
# Processing Record 27 of set 12 | svetlogorsk
# Processing Record 28 of set 12 | tubuala
# Processing Record 29 of set 12 | cabedelo
# Processing Record 30 of set 12 | port+shepstone
# Processing Record 31 of set 12 | nam+tha
# City not found. Skipping...
# Processing Record 32 of set 12 | zapolyarnyy
# Processing Record 33 of set 12 | calvinia
# Processing Record 34 of set 12 | osa
# Processing Record 35 of set 12 | half+moon+bay
# Processing Record 36 of set 12 | norden
# Processing Record 37 of set 12 | raga
# Processing Record 38 of set 12 | zuwarah
# Processing Record 39 of set 12 | arnedo
# Processing Record 40 of set 12 | andenes
# Processing Record 41 of set 12 | ye
# City not found. Skipping...
# Processing Record 42 of set 12 | khetri
# Processing Record 43 of set 12 | erdenet
# Processing Record 44 of set 12 | namie
# Processing Record 45 of set 12 | port-cartier
# Processing Record 46 of set 12 | san+vicente
# Processing Record 47 of set 12 | sharonville
# Processing Record 48 of set 12 | nhulunbuy
# Processing Record 49 of set 12 | broome
# Processing Record 50 of set 12 | kuytun
# Processing Record 1 of set 13 | westpunt
# City not found. Skipping...
# Processing Record 2 of set 13 | balyaga
# Processing Record 3 of set 13 | malanje
# Processing Record 4 of set 13 | catalina
# Processing Record 5 of set 13 | mayumba
# Processing Record 6 of set 13 | normandin
# Processing Record 7 of set 13 | fort+nelson
# Processing Record 8 of set 13 | ketchikan
# Processing Record 9 of set 13 | wanaka
# Processing Record 10 of set 13 | sterling
# Processing Record 11 of set 13 | boende
# Processing Record 12 of set 13 | atambua
# Processing Record 13 of set 13 | faya
# Processing Record 14 of set 13 | turukhansk
# Processing Record 15 of set 13 | colares
# Processing Record 16 of set 13 | ixtapa
# Processing Record 17 of set 13 | curaca
# Processing Record 18 of set 13 | blagoyevo
# Processing Record 19 of set 13 | jiuquan
# Processing Record 20 of set 13 | todos+santos
# Processing Record 21 of set 13 | virginia+beach
# Processing Record 22 of set 13 | sibolga
# Processing Record 23 of set 13 | yafran
# Processing Record 24 of set 13 | cuencame
# Processing Record 25 of set 13 | okhotsk
# Processing Record 26 of set 13 | xinzhou
# Processing Record 27 of set 13 | kenai
# Processing Record 28 of set 13 | linjiang
# Processing Record 29 of set 13 | binga
# Processing Record 30 of set 13 | anori
# Processing Record 31 of set 13 | olafsvik
# Processing Record 32 of set 13 | kailua
# Processing Record 33 of set 13 | riesi
# Processing Record 34 of set 13 | capitan+bado
# Processing Record 35 of set 13 | hosanagara
# Processing Record 36 of set 13 | lolodorf
# Processing Record 37 of set 13 | tahe
# Processing Record 38 of set 13 | concordia+sagittaria
# Processing Record 39 of set 13 | strasshof
# City not found. Skipping...
# Processing Record 40 of set 13 | lagonoy
# Processing Record 41 of set 13 | san+jose+de+guanipa
# Processing Record 42 of set 13 | at-bashi
# Processing Record 43 of set 13 | temeni
# Processing Record 44 of set 13 | insar
# Processing Record 45 of set 13 | vinh+long
# Processing Record 46 of set 13 | murray+bridge
# Processing Record 47 of set 13 | muyezerskiy
# Processing Record 48 of set 13 | bubaque
# Processing Record 49 of set 13 | lichtenburg
# Processing Record 50 of set 13 | coihaique
# Processing Record 1 of set 14 | yellapur
# Processing Record 2 of set 14 | mednogorsk
# Processing Record 3 of set 14 | fare
# Processing Record 4 of set 14 | berlevag
# Processing Record 5 of set 14 | bom+jesus
# Processing Record 6 of set 14 | prince+rupert
# Processing Record 7 of set 14 | zhenlai
# Processing Record 8 of set 14 | kemijarvi
# Processing Record 9 of set 14 | gushikawa
# Processing Record 10 of set 14 | gimli
# Processing Record 11 of set 14 | shakhtinsk
# Processing Record 12 of set 14 | mingaora
# Processing Record 13 of set 14 | manzil+salim
# Processing Record 14 of set 14 | ironton
# Processing Record 15 of set 14 | paamiut
# Processing Record 16 of set 14 | asau
# Processing Record 17 of set 14 | tommot
# Processing Record 18 of set 14 | roma
# Processing Record 19 of set 14 | priyutnoye
# Processing Record 20 of set 14 | jinzhou
# Processing Record 21 of set 14 | olinda
# Processing Record 22 of set 14 | thiruvananthapuram
# Processing Record 23 of set 14 | hailey
# Processing Record 24 of set 14 | saucillo
# Processing Record 25 of set 14 | yekepa
# Processing Record 26 of set 14 | sukhoverkovo
# City not found. Skipping...
# Processing Record 27 of set 14 | markova
# Processing Record 28 of set 14 | qeshm
# Processing Record 29 of set 14 | chimoio
# Processing Record 30 of set 14 | lenine
# Processing Record 31 of set 14 | locri
# Processing Record 32 of set 14 | mount+isa
# Processing Record 33 of set 14 | mandalgovi
# Processing Record 34 of set 14 | namatanai
# Processing Record 35 of set 14 | belaya+gora
# Processing Record 36 of set 14 | phan+rang
# City not found. Skipping...
# Processing Record 37 of set 14 | kang
# Processing Record 38 of set 14 | portland
# Processing Record 39 of set 14 | ranong
# Processing Record 40 of set 14 | lewistown
# Processing Record 41 of set 14 | inirida
# Processing Record 42 of set 14 | camacha
# Processing Record 43 of set 14 | harsin
# Processing Record 44 of set 14 | kadi
# Processing Record 45 of set 14 | vuktyl
# Processing Record 46 of set 14 | los+llanos+de+aridane
# Processing Record 47 of set 14 | chagda
# City not found. Skipping...
# Processing Record 48 of set 14 | shelburne
# Processing Record 49 of set 14 | arcot
# Processing Record 50 of set 14 | hobyo
# Processing Record 1 of set 15 | menongue
# Processing Record 2 of set 15 | kingsport
# Processing Record 3 of set 15 | lujan
# Processing Record 4 of set 15 | nelson+bay
# Processing Record 5 of set 15 | tambun
# Processing Record 6 of set 15 | scarborough
# Processing Record 7 of set 15 | avare
# Processing Record 8 of set 15 | lagoa
# Processing Record 9 of set 15 | abashiri
# Processing Record 10 of set 15 | freeport
# Processing Record 11 of set 15 | lengshuijiang
# Processing Record 12 of set 15 | kamien+pomorski
# Processing Record 13 of set 15 | winslow
# Processing Record 14 of set 15 | kyshtovka
# Processing Record 15 of set 15 | jiayuguan
# Processing Record 16 of set 15 | geresk
# City not found. Skipping...
# Processing Record 17 of set 15 | bodden+town
# Processing Record 18 of set 15 | porto+velho
# Processing Record 19 of set 15 | yagodnoye
# Processing Record 20 of set 15 | chicama
# Processing Record 21 of set 15 | aloleng
# Processing Record 22 of set 15 | dujuma
# City not found. Skipping...
# Processing Record 23 of set 15 | kakching
# Processing Record 24 of set 15 | piopio
# Processing Record 25 of set 15 | malpur
# Processing Record 26 of set 15 | ischia
# Processing Record 27 of set 15 | manono
# Processing Record 28 of set 15 | tocopilla
# Processing Record 29 of set 15 | brighton
# Processing Record 30 of set 15 | khor
# Processing Record 31 of set 15 | longyearbyen
# Processing Record 32 of set 15 | zheshart
# Processing Record 33 of set 15 | roswell
# Processing Record 34 of set 15 | champerico
# Processing Record 35 of set 15 | morada+nova
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# [{'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 78.87, 'Humidity': 76, 'Cloudiness': 3, 'Wind Speed': 12.93, 'Country': 'PF', 'Date': '2021-01-30 20:14:47', 'Current Description': 'light rain'}, {'City': 'Ponta+Do+Sol', 'Lat': 32.6667, 'Lng': -17.1, 'Max Temp': 61, 'Humidity': 75, 'Cloudiness': 69, 'Wind Speed': 1.79, 'Country': 'PT', 'Date': '2021-01-30 20:15:00', 'Current Description': 'broken clouds'}, {'City': 'Cooma', 'Lat': -36.2333, 'Lng': 149.1333, 'Max Temp': 55.4, 'Humidity': 100, 'Cloudiness': 90, 'Wind Speed': 1.99, 'Country': 'AU', 'Date': '2021-01-30 20:18:49', 'Current Description': 'overcast clouds'}, {'City': 'Kodinsk', 'Lat': 58.6881, 'Lng': 99.1844, 'Max Temp': -40.72, 'Humidity': 78, 'Cloudiness': 38, 'Wind Speed': 2.95, 'Country': 'RU', 'Date': '2021-01-30 20:18:50', 'Current Description': 'scattered clouds'}, {'City': 'Kontagora', 'Lat': 10.3999, 'Lng': 5.4695, 'Max Temp': 80.55, 'Humidity': 16, 'Cloudiness': 0, 'Wind Speed': 4.32, 'Country': 'NG', 'Date': '2021-01-30 20:14:07', 'Current Description': 'clear sky'}, {'City': 'Ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 53.6, 'Humidity': 58, 'Cloudiness': 20, 'Wind Speed': 26.46, 'Country': 'AR', 'Date': '2021-01-30 20:11:38', 'Current Description': 'few clouds'}, {'City': 'Punta+Arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max Temp': 59, 'Humidity': 47, 'Cloudiness': 0, 'Wind Speed': 31.07, 'Country': 'CL', 'Date': '2021-01-30 20:14:08', 'Current Description': 'clear sky'}, {'City': 'Stephenville+Crossing', 'Lat': 48.5, 'Lng': -58.4318, 'Max Temp': 26.6, 'Humidity': 86, 'Cloudiness': 90, 'Wind Speed': 10.36, 'Country': 'CA', 'Date': '2021-01-30 20:18:50', 'Current Description': 'overcast clouds'}, {'City': 'Mataura', 'Lat': -46.1927, 'Lng': 168.8643, 'Max Temp': 48, 'Humidity': 80, 'Cloudiness': 56, 'Wind Speed': 8.01, 'Country': 'NZ', 'Date': '2021-01-30 20:14:55', 'Current Description': 'broken clouds'}, {'City': 'Souillac', 'Lat': -20.5167, 'Lng': 57.5167, 'Max Temp': 78.8, 'Humidity': 89, 'Cloudiness': 75, 'Wind Speed': 8.05, 'Country': 'MU', 'Date': '2021-01-30 20:14:57', 'Current Description': 'light rain'}, {'City': 'Sinnamary', 'Lat': 5.3833, 'Lng': -52.95, 'Max Temp': 78.82, 'Humidity': 87, 'Cloudiness': 100, 'Wind Speed': 13.24, 'Country': 'GF', 'Date': '2021-01-30 20:15:59', 'Current Description': 'moderate rain'}, {'City': 'Eyl', 'Lat': 7.9803, 'Lng': 49.8164, 'Max Temp': 72.81, 'Humidity': 77, 'Cloudiness': 17, 'Wind Speed': 13.15, 'Country': 'SO', 'Date': '2021-01-30 20:15:16', 'Current Description': 'few clouds'}, {'City': 'Jais', 'Lat': 26.25, 'Lng': 81.5333, 'Max Temp': 49.64, 'Humidity': 50, 'Cloudiness': 0, 'Wind Speed': 5.48, 'Country': 'IN', 'Date': '2021-01-30 20:18:50', 'Current Description': 'clear sky'}, {'City': 'Laon', 'Lat': 49.5667, 'Lng': 3.6667, 'Max Temp': 46.4, 'Humidity': 93, 'Cloudiness': 90, 'Wind Speed': 2.3, 'Country': 'FR', 'Date': '2021-01-30 20:18:51', 'Current Description': 'overcast clouds'}, {'City': 'Codrington', 'Lat': -38.2667, 'Lng': 141.9667, 'Max Temp': 58.05, 'Humidity': 72, 'Cloudiness': 90, 'Wind Speed': 5.28, 'Country': 'AU', 'Date': '2021-01-30 20:14:48', 'Current Description': 'overcast clouds'}, {'City': 'Auki', 'Lat': -8.7676, 'Lng': 160.7034, 'Max Temp': 79.77, 'Humidity': 85, 'Cloudiness': 100, 'Wind Speed': 11.32, 'Country': 'SB', 'Date': '2021-01-30 20:15:15', 'Current Description': 'moderate rain'}, {'City': 'Nikolskoye', 'Lat': 59.7035, 'Lng': 30.7861, 'Max Temp': 28.4, 'Humidity': 93, 'Cloudiness': 75, 'Wind Speed': 4.47, 'Country': 'RU', 'Date': '2021-01-30 20:14:59', 'Current Description': 'snow'}, {'City': 'Dembi+Dolo', 'Lat': 8.5333, 'Lng': 34.8, 'Max Temp': 65.8, 'Humidity': 54, 'Cloudiness': 36, 'Wind Speed': 3.13, 'Country': 'ET', 'Date': '2021-01-30 20:18:51', 'Current Description': 'scattered clouds'}, {'City': 'Tuktoyaktuk', 'Lat': 69.4541, 'Lng': -133.0374, 'Max Temp': -36.4, 'Humidity': 74, 'Cloudiness': 40, 'Wind Speed': 1.54, 'Country': 'CA', 'Date': '2021 ...

# %%
# convert the city_data array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Rikitea -23.1203 -134.9692     78.87        76           3
# 1           Ponta+Do+Sol  32.6667  -17.1000     61.00        75          69
# 2                  Cooma -36.2333  149.1333     55.40       100          90
# 3                Kodinsk  58.6881   99.1844    -40.72        78          38
# 4              Kontagora  10.3999    5.4695     80.55        16           0
# 5                Ushuaia -54.8000  -68.3000     53.60        58          20
# 6           Punta+Arenas -53.1500  -70.9167     59.00        47           0
# 7  Stephenville+Crossing  48.5000  -58.4318     26.60        86          90
# 8                Mataura -46.1927  168.8643     48.00        80          56
# 9               Souillac -20.5167   57.5167     78.80        89          75
#
#    Wind Speed Country                 Date Current Description
# 0       12.93      PF  2021-01-30 20:14:47          light rain
# 1        1.79      PT  2021-01-30 20:15:00       broken clouds
# 2        1.99      AU  2021-01-30 20:18:49     overcast clouds
# 3        2.95      RU  2021-01-30 20:18:50    scattered clouds
# 4        4.32      NG  2021-01-30 20:14:07           clear sky
# 5       26.46      AR  2021-01-30 20:11:38          few clouds
# 6       31.07      CL  2021-01-30 20:14:08           clear sky
# 7       10.36      CA  2021-01-30 20:18:50     overcast clouds
# 8        8.01      NZ  2021-01-30 20:14:55       broken clouds
# 9        8.05      MU  2021-01-30 20:14:57          light rain

# %%
# reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Rikitea      PF -23.1203 -134.9692     78.87        76
# 1           Ponta+Do+Sol      PT  32.6667  -17.1000     61.00        75
# 2                  Cooma      AU -36.2333  149.1333     55.40       100
# 3                Kodinsk      RU  58.6881   99.1844    -40.72        78
# 4              Kontagora      NG  10.3999    5.4695     80.55        16
# 5                Ushuaia      AR -54.8000  -68.3000     53.60        58
# 6           Punta+Arenas      CL -53.1500  -70.9167     59.00        47
# 7  Stephenville+Crossing      CA  48.5000  -58.4318     26.60        86
# 8                Mataura      NZ -46.1927  168.8643     48.00        80
# 9               Souillac      MU -20.5167   57.5167     78.80        89
#
#    Cloudiness  Wind Speed Current Description
# 0           3       12.93          light rain
# 1          69        1.79       broken clouds
# 2          90        1.99     overcast clouds
# 3          38        2.95    scattered clouds
# 4           0        4.32           clear sky
# 5          20       26.46          few clouds
# 6           0       31.07           clear sky
# 7          90       10.36     overcast clouds
# 8          56        8.01       broken clouds
# 9          75        8.05          light rain

# %%
# create the output file csv
output_data_file = "WeatherPy_Database.csv"

#Export the City Data into a csv
city_data_df.to_csv(output_data_file,index_label="City_ID")
