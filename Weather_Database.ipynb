# %%
# import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

# import  weather_api_key
from config import weather_api_key

from datetime import datetime

# %%
# create a set of random lats and longs combintation

lats = np.random.uniform(-90 , 90, size =2000)
lngs = np.random.uniform(-180,180, size =2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Citypy module to find the nearest city
from citipy import citipy
coordinates = list(lats_lngs)

# %%
#create the list of cities which are unique
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
cities
len(cities)
# Out:
# 749

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# city_url = url+"&q="+"Boston"
# city_weather = requests.get(city_url).json()
# city_weather['weather'][0]['description']

# %%
#Create an empty list to hold the weather data
city_data =[]

#print the begining of the logging
print("Begining Data Retrieval")
print("-----------------------")

#create counters
record_count = 1 
set_count = 1


# Loop through all the cities in our list:
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes:
    if (i%50==0 and i>50):
        set_count +=1
        record_count =1
    city = city.replace(" ","+")
    # create endpoint URL with each city.
    city_url = url+"&q="+city
    
    #logging the URL record, and set numbers and the city
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    print(city_url)
    
    # Add 1  to the record count 
    record_count +=1
    
    # Run an API request for each of the cities.
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining Data Retrieval
# -----------------------
# Processing Record 1 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ushuaia
# Processing Record 2 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=saskylakh
# Processing Record 3 of set 1 | porto+novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=porto+novo
# Processing Record 4 of set 1 | bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bintulu
# Processing Record 5 of set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pevek
# Processing Record 6 of set 1 | shieli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=shieli
# Processing Record 7 of set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mataura
# Processing Record 8 of set 1 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pacifica
# Processing Record 9 of set 1 | barda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=barda
# Processing Record 10 of set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=butaritari
# Processing Record 11 of set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kodiak
# Processing Record 12 of set 1 | sirari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sirari
# Processing Record 13 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cidreira
# Processing Record 14 of set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sitka
# Processing Record 15 of set 1 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ruatoria
# City not found. Skipping...
# Processing Record 16 of set 1 | payakumbuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=payakumbuh
# Processing Record 17 of set 1 | alice+springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=alice+springs
# Processing Record 18 of set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ilulissat
# Processing Record 19 of set 1 | svetlograd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=svetlograd
# Processing Record 20 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=rikitea
# Processing Record 21 of set 1 | xian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=xian
# Processing Record 22 of set 1 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nemuro
# Processing Record 23 of set 1 | taganak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=taganak
# Processing Record 24 of set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=saint-philippe
# Processing Record 25 of set 1 | mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mugur-aksy
# Processing Record 26 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tuktoyaktuk
# Processing Record 27 of set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=isangel
# Processing Record 28 of set 1 | galgani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=galgani
# City not found. Skipping...
# Processing Record 29 of set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=victoria
# Processing Record 30 of set 1 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=harper
# Processing Record 31 of set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bathsheba
# Processing Record 32 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=albany
# Processing Record 33 of set 1 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=havoysund
# Processing Record 34 of set 1 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=rungata
# City not found. Skipping...
# Processing Record 35 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hobart
# Processing Record 36 of set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=amderma
# City not found. Skipping...
# Processing Record 37 of set 1 | vredendal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vredendal
# Processing Record 38 of set 1 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=marcona
# City not found. Skipping...
# Processing Record 39 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=avarua
# Processing Record 40 of set 1 | arraial+do+cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=arraial+do+cabo
# Processing Record 41 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=upernavik
# Processing Record 42 of set 1 | punta+arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=punta+arenas
# Processing Record 43 of set 1 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=buin
# Processing Record 44 of set 1 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=aripuana
# Processing Record 45 of set 1 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=celestun
# Processing Record 46 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=castro
# Processing Record 47 of set 1 | groa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=groa
# Processing Record 48 of set 1 | wakkanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=wakkanai
# Processing Record 49 of set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=dingle
# Processing Record 50 of set 1 | sindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sindou
# Processing Record 51 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=yellowknife
# Processing Record 52 of set 1 | mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mar+del+plata
# Processing Record 53 of set 1 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=thinadhoo
# Processing Record 54 of set 1 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=roma
# Processing Record 55 of set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=poum
# Processing Record 56 of set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hermanus
# Processing Record 57 of set 1 | karauzyak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=karauzyak
# City not found. Skipping...
# Processing Record 58 of set 1 | umarkot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=umarkot
# Processing Record 59 of set 1 | venado+tuerto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=venado+tuerto
# Processing Record 60 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=busselton
# Processing Record 61 of set 1 | east+london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=east+london
# Processing Record 62 of set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=lagoa
# Processing Record 63 of set 1 | koppies
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=koppies
# Processing Record 64 of set 1 | san+cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=san+cristobal
# Processing Record 65 of set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=khatanga
# Processing Record 66 of set 1 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ixtapa
# Processing Record 67 of set 1 | usogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=usogorsk
# Processing Record 68 of set 1 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=erenhot
# Processing Record 69 of set 1 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=aksarka
# Processing Record 70 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mahebourg
# Processing Record 71 of set 1 | puerto+ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=puerto+ayora
# Processing Record 72 of set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=chokurdakh
# Processing Record 73 of set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=georgetown
# Processing Record 74 of set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=luderitz
# Processing Record 75 of set 1 | borova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=borova
# Processing Record 76 of set 1 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=rawannawi
# City not found. Skipping...
# Processing Record 77 of set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kaitangata
# Processing Record 78 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kapaa
# Processing Record 79 of set 1 | khomeynishahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=khomeynishahr
# City not found. Skipping...
# Processing Record 80 of set 1 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=palauig
# Processing Record 81 of set 1 | ribeira+grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ribeira+grande
# Processing Record 82 of set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ahipara
# Processing Record 83 of set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tuatapere
# Processing Record 84 of set 1 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tromso
# Processing Record 85 of set 1 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=itarema
# Processing Record 86 of set 1 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=husavik
# Processing Record 87 of set 1 | port+alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=port+alfred
# Processing Record 88 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=carnarvon
# Processing Record 89 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=atuona
# Processing Record 90 of set 1 | tuy+hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tuy+hoa
# Processing Record 91 of set 1 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bolungarvik
# City not found. Skipping...
# Processing Record 92 of set 1 | zhob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=zhob
# Processing Record 93 of set 1 | la+grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=la+grande
# Processing Record 94 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vaini
# Processing Record 95 of set 1 | pujili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pujili
# Processing Record 96 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=barrow
# Processing Record 97 of set 1 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=samalaeulu
# City not found. Skipping...
# Processing Record 98 of set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=lompoc
# Processing Record 99 of set 1 | vila+franca+do+campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vila+franca+do+campo
# Processing Record 100 of set 1 | danjiangkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=danjiangkou
# Processing Record 1 of set 2 | mirabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mirabad
# Processing Record 2 of set 2 | haines+junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=haines+junction
# Processing Record 3 of set 2 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=saleaula
# City not found. Skipping...
# Processing Record 4 of set 2 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=faya
# Processing Record 5 of set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=dunedin
# Processing Record 6 of set 2 | luneville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=luneville
# Processing Record 7 of set 2 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=marzuq
# Processing Record 8 of set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bethel
# Processing Record 9 of set 2 | solovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=solovetskiy
# City not found. Skipping...
# Processing Record 10 of set 2 | tungkang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tungkang
# City not found. Skipping...
# Processing Record 11 of set 2 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sechura
# Processing Record 12 of set 2 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=labuhan
# Processing Record 13 of set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=thompson
# Processing Record 14 of set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bluff
# Processing Record 15 of set 2 | formosa+do+rio+preto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=formosa+do+rio+preto
# Processing Record 16 of set 2 | dzaoudzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=dzaoudzi
# Processing Record 17 of set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=leningradskiy
# Processing Record 18 of set 2 | cedar+city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cedar+city
# Processing Record 19 of set 2 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=deputatskiy
# Processing Record 20 of set 2 | abu+kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=abu+kamal
# Processing Record 21 of set 2 | belushya+guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=belushya+guba
# City not found. Skipping...
# Processing Record 22 of set 2 | nakskov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nakskov
# Processing Record 23 of set 2 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=yulara
# Processing Record 24 of set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hilo
# Processing Record 25 of set 2 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=maceio
# Processing Record 26 of set 2 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nyurba
# Processing Record 27 of set 2 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cayenne
# Processing Record 28 of set 2 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mayo
# Processing Record 29 of set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bredasdorp
# Processing Record 30 of set 2 | grand+river+south+east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=grand+river+south+east
# City not found. Skipping...
# Processing Record 31 of set 2 | kamakwie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kamakwie
# Processing Record 32 of set 2 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kropotkin
# Processing Record 33 of set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bengkulu
# Processing Record 34 of set 2 | santa+eulalia+del+rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=santa+eulalia+del+rio
# City not found. Skipping...
# Processing Record 35 of set 2 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=camana
# Processing Record 36 of set 2 | luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=luau
# Processing Record 37 of set 2 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hami
# Processing Record 38 of set 2 | igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=igarka
# Processing Record 39 of set 2 | ponta+do+sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ponta+do+sol
# Processing Record 40 of set 2 | vila+velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vila+velha
# Processing Record 41 of set 2 | abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=abha
# Processing Record 42 of set 2 | milingimbi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=milingimbi
# City not found. Skipping...
# Processing Record 43 of set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=barentsburg
# City not found. Skipping...
# Processing Record 44 of set 2 | sherlovaya+gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sherlovaya+gora
# Processing Record 45 of set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=torbay
# Processing Record 46 of set 2 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=samarai
# Processing Record 47 of set 2 | mount+gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mount+gambier
# Processing Record 48 of set 2 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ranong
# Processing Record 49 of set 2 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=palabuhanratu
# City not found. Skipping...
# Processing Record 50 of set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=jamestown
# Processing Record 1 of set 3 | urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=urengoy
# Processing Record 2 of set 3 | kalabagh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kalabagh
# Processing Record 3 of set 3 | penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=penzance
# Processing Record 4 of set 3 | cape+town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cape+town
# Processing Record 5 of set 3 | astoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=astoria
# Processing Record 6 of set 3 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of set 3 | sal+rei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sal+rei
# Processing Record 8 of set 3 | kultayevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kultayevo
# Processing Record 9 of set 3 | calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=calvinia
# Processing Record 10 of set 3 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=saint-pierre
# Processing Record 11 of set 3 | cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cururupu
# Processing Record 12 of set 3 | clyde+river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=clyde+river
# Processing Record 13 of set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=talnakh
# Processing Record 14 of set 3 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=watsa
# Processing Record 15 of set 3 | san+quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=san+quintin
# Processing Record 16 of set 3 | mys+shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mys+shmidta
# City not found. Skipping...
# Processing Record 17 of set 3 | shangrao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=shangrao
# Processing Record 18 of set 3 | pak+phanang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pak+phanang
# Processing Record 19 of set 3 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=coihaique
# Processing Record 20 of set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=dikson
# Processing Record 21 of set 3 | pitanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pitanga
# Processing Record 22 of set 3 | brokopondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=brokopondo
# Processing Record 23 of set 3 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ketchikan
# Processing Record 24 of set 3 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=taolanaro
# City not found. Skipping...
# Processing Record 25 of set 3 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hofn
# Processing Record 26 of set 3 | jacmel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=jacmel
# Processing Record 27 of set 3 | princeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=princeton
# Processing Record 28 of set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=katsuura
# Processing Record 29 of set 3 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=komsomolskiy
# Processing Record 30 of set 3 | planeta+rica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=planeta+rica
# Processing Record 31 of set 3 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=margate
# Processing Record 32 of set 3 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=zyryanka
# Processing Record 33 of set 3 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=fairbanks
# Processing Record 34 of set 3 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kiama
# Processing Record 35 of set 3 | guerrero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=guerrero
# Processing Record 36 of set 3 | novyy+urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=novyy+urengoy
# Processing Record 37 of set 3 | sao+joao+da+barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sao+joao+da+barra
# Processing Record 38 of set 3 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=attawapiskat
# City not found. Skipping...
# Processing Record 39 of set 3 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kutum
# Processing Record 40 of set 3 | sarandi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sarandi
# Processing Record 41 of set 3 | new+norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=new+norfolk
# Processing Record 42 of set 3 | humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=humaita
# Processing Record 43 of set 3 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mitsamiouli
# Processing Record 44 of set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nikolskoye
# Processing Record 45 of set 3 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=dicabisagan
# Processing Record 46 of set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=esperance
# Processing Record 47 of set 3 | onda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=onda
# Processing Record 48 of set 3 | bukachacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bukachacha
# Processing Record 49 of set 3 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nabire
# Processing Record 50 of set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=laguna
# Processing Record 1 of set 4 | galiwinku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=galiwinku
# City not found. Skipping...
# Processing Record 2 of set 4 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tasiilaq
# Processing Record 3 of set 4 | san+patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=san+patricio
# Processing Record 4 of set 4 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kangaatsiaq
# Processing Record 5 of set 4 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sobolevo
# Processing Record 6 of set 4 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=severo-kurilsk
# Processing Record 7 of set 4 | faridpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=faridpur
# Processing Record 8 of set 4 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=fortuna
# Processing Record 9 of set 4 | langsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=langsa
# Processing Record 10 of set 4 | san+andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=san+andres
# Processing Record 11 of set 4 | trapani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=trapani
# Processing Record 12 of set 4 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kahului
# Processing Record 13 of set 4 | karasjok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=karasjok
# Processing Record 14 of set 4 | sosnovo-ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sosnovo-ozerskoye
# Processing Record 15 of set 4 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=muravlenko
# Processing Record 16 of set 4 | envira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=envira
# Processing Record 17 of set 4 | capaci
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=capaci
# Processing Record 18 of set 4 | cascais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cascais
# Processing Record 19 of set 4 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hasaki
# Processing Record 20 of set 4 | lovec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=lovec
# City not found. Skipping...
# Processing Record 21 of set 4 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=yumen
# Processing Record 22 of set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=qaanaaq
# Processing Record 23 of set 4 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=taksimo
# Processing Record 24 of set 4 | wulanhaote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=wulanhaote
# City not found. Skipping...
# Processing Record 25 of set 4 | charters+towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=charters+towers
# Processing Record 26 of set 4 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tevaitoa
# Processing Record 27 of set 4 | port+elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=port+elizabeth
# Processing Record 28 of set 4 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=lasa
# Processing Record 29 of set 4 | cabo+san+lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cabo+san+lucas
# Processing Record 30 of set 4 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nizhneyansk
# City not found. Skipping...
# Processing Record 31 of set 4 | rio+grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=rio+grande
# Processing Record 32 of set 4 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=satitoa
# City not found. Skipping...
# Processing Record 33 of set 4 | bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bara
# Processing Record 34 of set 4 | san+carlos+de+bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=san+carlos+de+bariloche
# Processing Record 35 of set 4 | kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kiunga
# Processing Record 36 of set 4 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=akdepe
# Processing Record 37 of set 4 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=berlevag
# Processing Record 38 of set 4 | comodoro+rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=comodoro+rivadavia
# Processing Record 39 of set 4 | emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=emba
# Processing Record 40 of set 4 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=talcahuano
# Processing Record 41 of set 4 | ardistan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ardistan
# City not found. Skipping...
# Processing Record 42 of set 4 | norman+wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=norman+wells
# Processing Record 43 of set 4 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mrirt
# City not found. Skipping...
# Processing Record 44 of set 4 | gwadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=gwadar
# Processing Record 45 of set 4 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bonavista
# Processing Record 46 of set 4 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=basco
# Processing Record 47 of set 4 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vestmannaeyjar
# Processing Record 48 of set 4 | balabac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=balabac
# Processing Record 49 of set 4 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cherskiy
# Processing Record 50 of set 4 | marsh+harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=marsh+harbour
# Processing Record 1 of set 5 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pangnirtung
# Processing Record 2 of set 5 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ancud
# Processing Record 3 of set 5 | kouango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kouango
# Processing Record 4 of set 5 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=touros
# Processing Record 5 of set 5 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kununurra
# Processing Record 6 of set 5 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=samusu
# City not found. Skipping...
# Processing Record 7 of set 5 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=marawi
# Processing Record 8 of set 5 | omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=omboue
# Processing Record 9 of set 5 | vega+de+alatorre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vega+de+alatorre
# Processing Record 10 of set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=chuy
# Processing Record 11 of set 5 | pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pingliang
# Processing Record 12 of set 5 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=northam
# Processing Record 13 of set 5 | novoagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=novoagansk
# Processing Record 14 of set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=faanui
# Processing Record 15 of set 5 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vila
# Processing Record 16 of set 5 | la+romana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=la+romana
# Processing Record 17 of set 5 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=solnechnyy
# Processing Record 18 of set 5 | nikki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nikki
# Processing Record 19 of set 5 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sorland
# Processing Record 20 of set 5 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of set 5 | lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=lamar
# Processing Record 22 of set 5 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=shimoda
# Processing Record 23 of set 5 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=beloha
# Processing Record 24 of set 5 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vanavara
# Processing Record 25 of set 5 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sangar
# Processing Record 26 of set 5 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=luanda
# Processing Record 27 of set 5 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=port-gentil
# Processing Record 28 of set 5 | marsa+matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=marsa+matruh
# Processing Record 29 of set 5 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=camacha
# Processing Record 30 of set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=airai
# Processing Record 31 of set 5 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kavieng
# Processing Record 32 of set 5 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tual
# Processing Record 33 of set 5 | bambous+virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bambous+virieux
# Processing Record 34 of set 5 | mocambique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mocambique
# City not found. Skipping...
# Processing Record 35 of set 5 | colombo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=colombo
# Processing Record 36 of set 5 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sistranda
# Processing Record 37 of set 5 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=waddan
# Processing Record 38 of set 5 | abu+dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=abu+dhabi
# Processing Record 39 of set 5 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=namatanai
# Processing Record 40 of set 5 | san+vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=san+vicente
# Processing Record 41 of set 5 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=aksu
# Processing Record 42 of set 5 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=peniche
# Processing Record 43 of set 5 | toyooka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=toyooka
# Processing Record 44 of set 5 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=paamiut
# Processing Record 45 of set 5 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kloulklubed
# Processing Record 46 of set 5 | sao+felix+do+xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sao+felix+do+xingu
# Processing Record 47 of set 5 | madimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=madimba
# Processing Record 48 of set 5 | yarke+pole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=yarke+pole
# Processing Record 49 of set 5 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bereda
# Processing Record 50 of set 5 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=whitehorse
# Processing Record 1 of set 6 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=umzimvubu
# City not found. Skipping...
# Processing Record 2 of set 6 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nanortalik
# Processing Record 3 of set 6 | pamfila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pamfila
# Processing Record 4 of set 6 | assiniboia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=assiniboia
# Processing Record 5 of set 6 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=srednekolymsk
# Processing Record 6 of set 6 | mandalgovi
# ...
# Processing Record 49 of set 12 | cerrito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cerrito
# Processing Record 50 of set 12 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mahajanga
# Processing Record 1 of set 13 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tiksi
# Processing Record 2 of set 13 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=najran
# Processing Record 3 of set 13 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=goderich
# Processing Record 4 of set 13 | verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=verkhnevilyuysk
# Processing Record 5 of set 13 | tavda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tavda
# Processing Record 6 of set 13 | puerto+del+rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=puerto+del+rosario
# Processing Record 7 of set 13 | ozernovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ozernovskiy
# Processing Record 8 of set 13 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sungaipenuh
# Processing Record 9 of set 13 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=russell
# Processing Record 10 of set 13 | calabar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=calabar
# Processing Record 11 of set 13 | kamalpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kamalpur
# Processing Record 12 of set 13 | kingaroy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kingaroy
# Processing Record 13 of set 13 | khorixas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=khorixas
# Processing Record 14 of set 13 | santa+cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=santa+cruz
# Processing Record 15 of set 13 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bud
# Processing Record 16 of set 13 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kimbe
# Processing Record 17 of set 13 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=gigmoto
# Processing Record 18 of set 13 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=namibe
# Processing Record 19 of set 13 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=halalo
# City not found. Skipping...
# Processing Record 20 of set 13 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=kawalu
# Processing Record 21 of set 13 | jackson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=jackson
# Processing Record 22 of set 13 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=panaba
# Processing Record 23 of set 13 | toulepleu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=toulepleu
# City not found. Skipping...
# Processing Record 24 of set 13 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=taltal
# Processing Record 25 of set 13 | rimbey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=rimbey
# Processing Record 26 of set 13 | seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=seymchan
# Processing Record 27 of set 13 | hondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hondo
# Processing Record 28 of set 13 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vao
# Processing Record 29 of set 13 | shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=shakawe
# Processing Record 30 of set 13 | prieska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=prieska
# Processing Record 31 of set 13 | goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=goundam
# Processing Record 32 of set 13 | dianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=dianopolis
# City not found. Skipping...
# Processing Record 33 of set 13 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=iskateley
# Processing Record 34 of set 13 | muncar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=muncar
# Processing Record 35 of set 13 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=egvekinot
# Processing Record 36 of set 13 | elmadag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=elmadag
# Processing Record 37 of set 13 | osoyoos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=osoyoos
# Processing Record 38 of set 13 | ringe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ringe
# Processing Record 39 of set 13 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mangrol
# Processing Record 40 of set 13 | miraflores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=miraflores
# Processing Record 41 of set 13 | rantepao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=rantepao
# Processing Record 42 of set 13 | hurricane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hurricane
# Processing Record 43 of set 13 | qui+nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=qui+nhon
# Processing Record 44 of set 13 | longonjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=longonjo
# Processing Record 45 of set 13 | bristol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bristol
# Processing Record 46 of set 13 | bari+sadri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bari+sadri
# Processing Record 47 of set 13 | bobonong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bobonong
# City not found. Skipping...
# Processing Record 48 of set 13 | neyshabur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=neyshabur
# Processing Record 49 of set 13 | san+benedetto+del+tronto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=san+benedetto+del+tronto
# Processing Record 50 of set 13 | lhuntshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=lhuntshi
# City not found. Skipping...
# Processing Record 1 of set 14 | encarnacion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=encarnacion
# Processing Record 2 of set 14 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tommot
# Processing Record 3 of set 14 | thohoyandou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=thohoyandou
# Processing Record 4 of set 14 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=yerbogachen
# Processing Record 5 of set 14 | changli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=changli
# Processing Record 6 of set 14 | teshie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=teshie
# Processing Record 7 of set 14 | tarudant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tarudant
# City not found. Skipping...
# Processing Record 8 of set 14 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=leshukonskoye
# Processing Record 9 of set 14 | west+plains
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=west+plains
# Processing Record 10 of set 14 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=morondava
# Processing Record 11 of set 14 | laranjeiras+do+sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=laranjeiras+do+sul
# Processing Record 12 of set 14 | olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=olga
# Processing Record 13 of set 14 | hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hailar
# Processing Record 14 of set 14 | pozo+colorado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=pozo+colorado
# Processing Record 15 of set 14 | juba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=juba
# Processing Record 16 of set 14 | novosibirsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=novosibirsk
# Processing Record 17 of set 14 | koygorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=koygorodok
# Processing Record 18 of set 14 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=eydhafushi
# Processing Record 19 of set 14 | hornepayne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=hornepayne
# Processing Record 20 of set 14 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mwinilunga
# Processing Record 21 of set 14 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=derzhavinsk
# Processing Record 22 of set 14 | balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=balkanabat
# Processing Record 23 of set 14 | bartica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=bartica
# Processing Record 24 of set 14 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sinnamary
# Processing Record 25 of set 14 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=yaan
# Processing Record 26 of set 14 | toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=toamasina
# Processing Record 27 of set 14 | cavalcante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cavalcante
# Processing Record 28 of set 14 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=svetlaya
# Processing Record 29 of set 14 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sabang
# Processing Record 30 of set 14 | ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ostersund
# Processing Record 31 of set 14 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=urumqi
# Processing Record 32 of set 14 | sahrak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sahrak
# City not found. Skipping...
# Processing Record 33 of set 14 | banda+aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=banda+aceh
# Processing Record 34 of set 14 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=sorvag
# City not found. Skipping...
# Processing Record 35 of set 14 | dakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=dakar
# Processing Record 36 of set 14 | boa+vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=boa+vista
# Processing Record 37 of set 14 | shizunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=shizunai
# Processing Record 38 of set 14 | red+bank
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=red+bank
# Processing Record 39 of set 14 | severnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=severnyy
# Processing Record 40 of set 14 | monchegorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=monchegorsk
# Processing Record 41 of set 14 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=mitu
# Processing Record 42 of set 14 | concepcion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=concepcion
# Processing Record 43 of set 14 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=tezu
# Processing Record 44 of set 14 | makhalino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=makhalino
# Processing Record 45 of set 14 | gazipur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=gazipur
# Processing Record 46 of set 14 | ferkessedougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=ferkessedougou
# Processing Record 47 of set 14 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=vysokogornyy
# Processing Record 48 of set 14 | nadvoitsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=nadvoitsy
# Processing Record 49 of set 14 | cam+ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c9d860d75e2657f902e68685d06f935&q=cam+ranh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# [{'City': 'Ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 51.8, 'Humidity': 62, 'Cloudiness': 20, 'Wind Speed': 26.46, 'Country': 'AR', 'Date': '2021-01-30 17:10:04', 'Current Description': 'few clouds'}, {'City': 'Saskylakh', 'Lat': 71.9167, 'Lng': 114.0833, 'Max Temp': -38.56, 'Humidity': 78, 'Cloudiness': 35, 'Wind Speed': 7.99, 'Country': 'RU', 'Date': '2021-01-30 17:10:04', 'Current Description': 'scattered clouds'}, {'City': 'Porto+Novo', 'Lat': 6.4965, 'Lng': 2.6036, 'Max Temp': 83.95, 'Humidity': 72, 'Cloudiness': 19, 'Wind Speed': 11.52, 'Country': 'BJ', 'Date': '2021-01-30 17:10:04', 'Current Description': 'few clouds'}, {'City': 'Bintulu', 'Lat': 3.1667, 'Lng': 113.0333, 'Max Temp': 78.8, 'Humidity': 94, 'Cloudiness': 20, 'Wind Speed': 2.3, 'Country': 'MY', 'Date': '2021-01-30 17:10:04', 'Current Description': 'few clouds'}, {'City': 'Pevek', 'Lat': 69.7008, 'Lng': 170.3133, 'Max Temp': -32.48, 'Humidity': 85, 'Cloudiness': 44, 'Wind Speed': 3.8, 'Country': 'RU', 'Date': '2021-01-30 17:10:05', 'Current Description': 'scattered clouds'}, {'City': 'Shieli', 'Lat': 44.1667, 'Lng': 66.75, 'Max Temp': 36.82, 'Humidity': 74, 'Cloudiness': 100, 'Wind Speed': 8.14, 'Country': 'KZ', 'Date': '2021-01-30 17:10:05', 'Current Description': 'overcast clouds'}, {'City': 'Mataura', 'Lat': -46.1927, 'Lng': 168.8643, 'Max Temp': 48, 'Humidity': 80, 'Cloudiness': 50, 'Wind Speed': 8.01, 'Country': 'NZ', 'Date': '2021-01-30 17:10:05', 'Current Description': 'scattered clouds'}, {'City': 'Pacifica', 'Lat': 37.6138, 'Lng': -122.4869, 'Max Temp': 51.01, 'Humidity': 81, 'Cloudiness': 75, 'Wind Speed': 6.17, 'Country': 'US', 'Date': '2021-01-30 17:07:28', 'Current Description': 'broken clouds'}, {'City': 'Barda', 'Lat': 40.3744, 'Lng': 47.1267, 'Max Temp': 42.75, 'Humidity': 89, 'Cloudiness': 100, 'Wind Speed': 5.73, 'Country': 'AZ', 'Date': '2021-01-30 17:10:05', 'Current Description': 'overcast clouds'}, {'City': 'Butaritari', 'Lat': 3.0707, 'Lng': 172.7902, 'Max Temp': 80.69, 'Humidity': 78, 'Cloudiness': 94, 'Wind Speed': 17.05, 'Country': 'KI', 'Date': '2021-01-30 17:10:05', 'Current Description': 'overcast clouds'}, {'City': 'Kodiak', 'Lat': 57.79, 'Lng': -152.4072, 'Max Temp': 32, 'Humidity': 55, 'Cloudiness': 1, 'Wind Speed': 25.32, 'Country': 'US', 'Date': '2021-01-30 17:05:44', 'Current Description': 'clear sky'}, {'City': 'Sirari', 'Lat': -1.2333, 'Lng': 34.4333, 'Max Temp': 67.15, 'Humidity': 76, 'Cloudiness': 98, 'Wind Speed': 2.64, 'Country': 'TZ', 'Date': '2021-01-30 17:10:05', 'Current Description': 'overcast clouds'}, {'City': 'Cidreira', 'Lat': -30.1811, 'Lng': -50.2056, 'Max Temp': 85.26, 'Humidity': 67, 'Cloudiness': 35, 'Wind Speed': 8.57, 'Country': 'BR', 'Date': '2021-01-30 17:10:06', 'Current Description': 'scattered clouds'}, {'City': 'Sitka', 'Lat': 57.0531, 'Lng': -135.33, 'Max Temp': 37.4, 'Humidity': 60, 'Cloudiness': 75, 'Wind Speed': 6.91, 'Country': 'US', 'Date': '2021-01-30 17:10:06', 'Current Description': 'broken clouds'}, {'City': 'Payakumbuh', 'Lat': -0.2202, 'Lng': 100.6308, 'Max Temp': 69.46, 'Humidity': 84, 'Cloudiness': 100, 'Wind Speed': 0.98, 'Country': 'ID', 'Date': '2021-01-30 17:10:06', 'Current Description': 'overcast clouds'}, {'City': 'Alice+Springs', 'Lat': -23.7, 'Lng': 133.8833, 'Max Temp': 86, 'Humidity': 32, 'Cloudiness': 90, 'Wind Speed': 14.97, 'Country': 'AU', 'Date': '2021-01-30 17:10:06', 'Current Description': 'overcast clouds'}, {'City': 'Ilulissat', 'Lat': 69.2167, 'Lng': -51.1, 'Max Temp': 3.2, 'Humidity': 60, 'Cloudiness': 40, 'Wind Speed': 8.05, 'Country': 'GL', 'Date': '2021-01-30 17:10:06', 'Current Description': 'scattered clouds'}, {'City': 'Svetlograd', 'Lat': 45.3353, 'Lng': 42.8547, 'Max Temp': 35.6, 'Humidity': 87, 'Cloudiness': 40, 'Wind Speed': 11.18, 'Country': 'RU', 'Date': '2021-01-30 17:10:06', 'Current Description': 'scattered clouds'}, {'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 79.07, 'Humidity': 74, 'Cloudiness': 74, 'Wind Speed': 10 ...

# %%
# convert the city_data array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ushuaia -54.8000  -68.3000     51.80        62          20       26.46
# 1   Saskylakh  71.9167  114.0833    -38.56        78          35        7.99
# 2  Porto+Novo   6.4965    2.6036     83.95        72          19       11.52
# 3     Bintulu   3.1667  113.0333     78.80        94          20        2.30
# 4       Pevek  69.7008  170.3133    -32.48        85          44        3.80
# 5      Shieli  44.1667   66.7500     36.82        74         100        8.14
# 6     Mataura -46.1927  168.8643     48.00        80          50        8.01
# 7    Pacifica  37.6138 -122.4869     51.01        81          75        6.17
# 8       Barda  40.3744   47.1267     42.75        89         100        5.73
# 9  Butaritari   3.0707  172.7902     80.69        78          94       17.05
#
#   Country                 Date Current Description
# 0      AR  2021-01-30 17:10:04          few clouds
# 1      RU  2021-01-30 17:10:04    scattered clouds
# 2      BJ  2021-01-30 17:10:04          few clouds
# 3      MY  2021-01-30 17:10:04          few clouds
# 4      RU  2021-01-30 17:10:05    scattered clouds
# 5      KZ  2021-01-30 17:10:05     overcast clouds
# 6      NZ  2021-01-30 17:10:05    scattered clouds
# 7      US  2021-01-30 17:07:28       broken clouds
# 8      AZ  2021-01-30 17:10:05     overcast clouds
# 9      KI  2021-01-30 17:10:05     overcast clouds

# %%
# reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ushuaia      AR -54.8000  -68.3000     51.80        62          20
# 1   Saskylakh      RU  71.9167  114.0833    -38.56        78          35
# 2  Porto+Novo      BJ   6.4965    2.6036     83.95        72          19
# 3     Bintulu      MY   3.1667  113.0333     78.80        94          20
# 4       Pevek      RU  69.7008  170.3133    -32.48        85          44
# 5      Shieli      KZ  44.1667   66.7500     36.82        74         100
# 6     Mataura      NZ -46.1927  168.8643     48.00        80          50
# 7    Pacifica      US  37.6138 -122.4869     51.01        81          75
# 8       Barda      AZ  40.3744   47.1267     42.75        89         100
# 9  Butaritari      KI   3.0707  172.7902     80.69        78          94
#
#    Wind Speed Current Description
# 0       26.46          few clouds
# 1        7.99    scattered clouds
# 2       11.52          few clouds
# 3        2.30          few clouds
# 4        3.80    scattered clouds
# 5        8.14     overcast clouds
# 6        8.01    scattered clouds
# 7        6.17       broken clouds
# 8        5.73     overcast clouds
# 9       17.05     overcast clouds

# %%
# create the output file csv
output_data_file = "weather_Database/WeatherPy_Database.csv"

#Export the City Data into a csv
city_data_df.to_csv(output_data_file,index_label="City_ID")
